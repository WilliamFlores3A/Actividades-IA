# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamFlores3A/Actividades-IA/blob/main/Actividad2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('musica.csv')
data.head(4)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan       Santana
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000083     0.552    0.357   77.169     198973.0             4.0
# 1          0.003720     0.123    0.473   75.023     166606.0             4.0
# ...

# %%
data.sort_values('name', ascending = True)
# Out:
#                                                    id  \
# 60                              2BgEsaKNfHUdlh97KmvFy
# 34                              2hl6q70unbviGo3g1R7uF
# 15                              3GCdLUSnKSMJhs4Tj6CV3
# 47                              4hQ6UGyWQIGJmHSo0J88J
# 99                              3EPXxR3ImUwfayaurPi3c
# ..                                                ...
# 2                               0e7ipj03S05BNilyu5bRz
# 20  5CLGzJsGqhCEECcpnFQA8,"These Days (feat. Jess ...
# 69  4w8niZpiMy6qz1mntFA5u,"Taki Taki (with Selena ...
# 70  5Gu0PDLN4YJeW75PpBSg9,"Let Me Go (with Alesso,...
# 77  4QtiVmuA88tPQiCOHZuQ5,"1, 2, 3 (feat. Jason De...
#
#                                                  name         artists  \
# 60                                               2002      Anne-Marie
# 34                                    ?chame La Culpa      Luis Fonsi
# 15                           All The Stars (with SZA)  Kendrick Lamar
# ...

# %%
data.sort_values('artists', ascending = True)
# Out:
#                                                    id  \
# 23                              2iUXsYOEPhVqEBwsqP70r
# 55                              2E124GmJRnBJuXbTb4cPU
# 88                              3Ga6eKrUFf12ouh9Yw3v2
# 60                              2BgEsaKNfHUdlh97KmvFy
# 65                              5OCJzvD7sykQEKHH7qAC3
# ..                                                ...
# 35                              0d2iYfpKoM0QCKvcLCkBa
# 20  5CLGzJsGqhCEECcpnFQA8,"These Days (feat. Jess ...
# 69  4w8niZpiMy6qz1mntFA5u,"Taki Taki (with Selena ...
# 70  5Gu0PDLN4YJeW75PpBSg9,"Let Me Go (with Alesso,...
# 77  4QtiVmuA88tPQiCOHZuQ5,"1, 2, 3 (feat. Jason De...
#
#                                       name              artists  danceability  \
# 23                              Youngblood  5 Seconds of Summer         0.596
# 55  FEFE (feat. Nicki Minaj & Murda Beatz)              6ix9ine         0.931
# 88                                Downtown               Anitta         0.775
# ...

# %%
data.sort_values('tempo', ascending = True)
# Out:
#                                                    id  \
# 38                              7AFASza1mXqntmGtbxXpr
# 1                               3ee8Jmje8o58CHK66QrVC
# 0                               6DCZcSspjsKoFjzjrWoCd
# 71                              6QgjcU0zLnzq5OrUoSZ3O
# 78                              6Za3190Sbw39BBC77WSS1
# ..                                                ...
# 85                              5cepAtqnEQ6yVG6088zMM
# 20  5CLGzJsGqhCEECcpnFQA8,"These Days (feat. Jess ...
# 69  4w8niZpiMy6qz1mntFA5u,"Taki Taki (with Selena ...
# 70  5Gu0PDLN4YJeW75PpBSg9,"Let Me Go (with Alesso,...
# 77  4QtiVmuA88tPQiCOHZuQ5,"1, 2, 3 (feat. Jason De...
#
#                              name            artists  danceability  energy  \
# 38                        changes       XXXTENTACION         0.669   0.308
# 1                            SAD!       XXXTENTACION         0.740   0.613
# 0                      God's Plan            Santana         0.754   0.449
# ...
